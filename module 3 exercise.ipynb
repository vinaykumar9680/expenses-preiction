# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
d1=pd.read_csv('C:/Users/VINAY KUMAR PATEL/Downloads/machine learning/expenses.csv',header=0)

# %%
d1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
d1.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.pairplot(d1)

# %%
d1=pd.get_dummies(d1).astype(int)

# %%
d1
# Out:
#       age  bmi  children  charges  sex_female  sex_male  smoker_no  \
# 0      19   27         0    16884           1         0          0
# 1      18   33         1     1725           0         1          1
# 2      28   33         3     4449           0         1          1
# 3      33   22         0    21984           0         1          1
# 4      32   28         0     3866           0         1          1
# ...   ...  ...       ...      ...         ...       ...        ...
# 1333   50   30         3    10600           0         1          1
# 1334   18   31         0     2205           1         0          1
# 1335   18   36         0     1629           1         0          1
# 1336   21   25         0     2007           1         0          1
# 1337   61   29         0    29141           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0              1                 0                 0                 0
# ...

# %%
# Check for null values
null_values = d1.isnull().sum()
null_values
# Out:
# age                 0
# bmi                 0
# children            0
# charges             0
# sex_female          0
# sex_male            0
# smoker_no           0
# smoker_yes          0
# region_northeast    0
# region_northwest    0
# region_southeast    0
# region_southwest    0
# dtype: int64

# %%
# Ensure all columns are of numeric type
df_with_dummies = d1.apply(pd.to_numeric, errors='coerce')

null_values, df_with_dummies.head()
# Out:
# (age                 0
#  bmi                 0
#  children            0
#  charges             0
#  sex_female          0
#  sex_male            0
#  smoker_no           0
#  smoker_yes          0
#  region_northeast    0
#  region_northwest    0
#  region_southeast    0
#  region_southwest    0
#  dtype: int64,
#     age  bmi  children  charges  sex_female  sex_male  smoker_no  smoker_yes  \
#  0   19   27         0    16884           1         0          0           1
#  1   18   33         1     1725           0         1          1           0
#  2   28   33         3     4449           0         1          1           0
#  3   33   22         0    21984           0         1          1           0
#  4   32   28         0     3866           0         1          1           0
#
#     region_northeast  region_northwest  region_southeast  region_southwest
#  0                 0                 0                 0                 1
# ...

# %%
del d1['sex_male']

# %%
del d1['smoker_no']

# %%
d1.head()
# Out:
#    age  bmi  children  charges  sex_female  smoker_yes  region_northeast  \
# 0   19   27         0    16884           1           1                 0
# 1   18   33         1     1725           0           0                 0
# 2   28   33         3     4449           0           0                 0
# 3   33   22         0    21984           0           0                 0
# 4   32   28         0     3866           0           0                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %%
# Out:
#                        age       bmi  children   charges  sex_female  \
# age               1.000000  0.108437  0.042469  0.299009    0.020856
# bmi               0.108437  1.000000  0.011097  0.196188   -0.046503
# children          0.042469  0.011097  1.000000  0.067999   -0.017163
# charges           0.299009  0.196188  0.067999  1.000000   -0.057293
# sex_female        0.020856 -0.046503 -0.017163 -0.057293    1.000000
# smoker_yes       -0.025019  0.001669  0.007673  0.787251   -0.076185
# region_northeast  0.002475 -0.138877 -0.022808  0.006350    0.002425
# region_northwest -0.000407 -0.138495  0.024806 -0.039905    0.011156
# region_southeast -0.011642  0.271303 -0.023066  0.073981   -0.017117
# region_southwest  0.010016 -0.004313  0.021914 -0.043210    0.004184
#
#                   smoker_yes  region_northeast  region_northwest  \
# age                -0.025019          0.002475         -0.000407
# bmi                 0.001669         -0.138877         -0.138495
# ...

# %%
import statsmodels.api as sn

# %%
X = sn.add_constant(d1['bmi'])

# %%
lm = sn.OLS(d1['charges'], X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     53.48
# Date:                Mon, 19 Aug 2024   Prob (F-statistic):           4.48e-13
# Time:                        20:49:26   Log-Likelihood:                -14451.
# No. Observations:                1338   AIC:                         2.891e+04
# Df Residuals:                    1336   BIC:                         2.892e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1557.5329   1634.165      0.953      0.341   -1648.275    4763.341
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
x= d1['bmi']

# %%
y= d1[['charges']]

# %%
x = x.astype(float)
y = y.astype(float)

# %%
lm2=LinearRegression()

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model._base object:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, copy_X=True, n_jobs=None, positive=False)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  copy_X : bool, default=True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
#  |  n_jobs : int, default=None
# ...

# %%
lm2.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 lm2.fit(x,y)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
# ...

# %%
print(lm2.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(lm2.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
sns.jointplot(x='bmi', y='charges', data=d1)

# %%
lm.predict(x)
# Out:
# 0       12039.412197
# 1       14368.718701
# 2       14368.718701
# 3       10098.323443
# 4       12427.629947
#             ...
# 1333    13204.065449
# 1334    13592.283200
# 1335    15533.371953
# 1336    11262.976695
# 1337    12815.847698
# Length: 1338, dtype: float64

# %%
sns.jointplot(x=d1['bmi'],y=d1['charges'],data= d1,kind='reg')

# %%
from sklearn.model_selection import train_test_split

# %%
y=sn.add_constant(d1['charges'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1070, 2) (268, 2) (1070, 2) (268, 2)

# %%
lm_a= LinearRegression()

# %%
lm_a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a=lm_a.predict(x_test)

# %%
y_train_a=lm_a.predict(x_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score=(y_test,y_test_a)

# %%
r2_score=(y_train,y_train_a)
